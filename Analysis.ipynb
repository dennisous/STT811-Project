# %%
import pandas as pd

df = pd.read_parquet('combined.parquet')
print(df.shape)
df.head()
# Out:
# (6940494, 31)
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2025        1      1             1            3  1/1/2025 12:00:00 AM
# 1  2025        1      1             1            3  1/1/2025 12:00:00 AM
# 2  2025        1      1             1            3  1/1/2025 12:00:00 AM
# 3  2025        1      1             1            3  1/1/2025 12:00:00 AM
# 4  2025        1      1             1            3  1/1/2025 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  ORIGIN_CITY_NAME   DEST_CITY_NAME  CRS_DEP_TIME  ...  \
# 0                AA      New York, NY  Los Angeles, CA           659  ...
# 1                AA   Los Angeles, CA     New York, NY          2200  ...
# 2                AA       Madison, WI    Charlotte, NC           644  ...
# 3                AA  Philadelphia, PA    Las Vegas, NV          1855  ...
# 4                AA       Chicago, IL      Phoenix, AZ           830  ...
#
#    CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0            NaN            NaN        NaN             NaN
# 1            NaN            NaN        NaN             NaN
# 2           20.0            0.0        0.0             0.0
# 3            NaN            NaN        NaN             NaN
# 4            0.0            0.0       44.0             0.0
#
#    LATE_AIRCRAFT_DELAY  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  ARR_DELAY  \
# 0                  NaN                  NaN                  NaN        NaN
# 1                  NaN                  NaN                  NaN        NaN
# 2                  0.0                  NaN                  NaN        NaN
# 3                  NaN                  NaN                  NaN        NaN
# 4                  0.0                  NaN                  NaN        NaN
#
#    DIVERTED AIR_TIME
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
#
# [5 rows x 31 columns]

# %%
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
# Out:
# <positron-console-cell-2>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
df = df.drop_duplicates()
print(df.shape)
# Out:
# (6400744, 31)

# %%
df[['ORIGIN_CITY', 'ORIGIN_STATE']] = df['ORIGIN_CITY_NAME'].str.split(',', expand=True)
df[['DEST_CITY', 'DEST_STATE']] = df['DEST_CITY_NAME'].str.split(',', expand=True)

df['ORIGIN_STATE'] = df['ORIGIN_STATE'].str.strip()
df['DEST_STATE'] = df['DEST_STATE'].str.strip()

# %%
df.isna().sum()
# Out:
# YEAR                         0
# QUARTER                      0
# MONTH                        0
# DAY_OF_MONTH                 0
# DAY_OF_WEEK                  0
# FL_DATE                      0
# OP_UNIQUE_CARRIER            0
# ORIGIN_CITY_NAME             0
# DEST_CITY_NAME               0
# CRS_DEP_TIME                 0
# DEP_TIME                 91584
# DEP_DELAY                91979
# DEP_DEL15                91979
# WHEELS_OFF             5379655
# WHEELS_ON              5380234
# CRS_ARR_TIME                 0
# ARR_TIME                 97474
# ARR_DEL15               113561
# CANCELLED                    0
# CANCELLATION_CODE      6304794
# DISTANCE                     0
# CARRIER_DELAY          4982140
# WEATHER_DELAY          4982140
# NAS_DELAY              4982140
# SECURITY_DELAY         4982140
# LATE_AIRCRAFT_DELAY    4982140
# DEST_AIRPORT_SEQ_ID    1044629
# DEST_CITY_MARKET_ID    1044629
# ARR_DELAY              1132306
# DIVERTED               1044629
# AIR_TIME               1132306
# ORIGIN_CITY                  0
# ORIGIN_STATE                 0
# DEST_CITY                    0
# DEST_STATE                   0
# dtype: int64

# %%
df.to_parquet('combined_preprocessed.parquet', index=False, compression='zstd')
